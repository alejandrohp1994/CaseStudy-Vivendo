# %% [markdown]
# # Data Analyst Associate Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## Task 1

# %% [markdown]
# For every column in the data:
# 1. State whether the values match the description given in the table above.
# 2. State the number of missing values in the column.
# 3. Describe what you did to make values match the description if they did not match.

# %% [markdown]
# **SOLUTION:**
#
# **claim_id :** There were 2000 different unique identifiers. This column had no missing values. No changes were made to this column.
#
# **time_to_close :** There were 256 unique values. This column had no missing values and all of them were positive. No changes were made to this column.
#
# **claim_amount :** There were 2000 unique values. This column had no missing values. However, this column has the currency attached to the value. This currency was removed for calculation purposes. In addition, all amounts in this column were rounded to two decimal places.
#
# **amount_paid :** There were 1964 unique values, but there are 36 missing values on this column. As requested, these amounts were replaced with the overall median amount of this column. The amount was 20105.70. In addition, all amounts in this column were rounded to two decimal places.
#
# **location :** There were 4 unique values on this columns. This column had no missing values. These values were: 'RECIFE', 'FORTALEZA', 'SAO LUIS' and 'NATAL'. These values matched the location names specified. No changes were made to this column.
#
# **individuals_on_claim :** There are 15 unique values on this column. This column had no missing values. The minimum value for this column was 1. No changes were made to this column.
#
# **linked_cases :** There were 3 unique values for this column. This column had 26 missing values. As requested, these values were replaced with FALSE.
#
# **cause :** There were 5 unique values found on this table. There were no missing values on this column. Aside from the: 'unknown', 'meat' and 'vegetable' values; there were ' Meat' and 'VEGETABLES'. these values were replaced with 'meat' and 'vegetable' as there were mismatching, not missing.

# %% [markdown]
# ## Task 2

# %% [markdown]
# Create a visualization that shows the number of claims in each location. Use the visualization to:
# 1. State which category of the variable location has the most observations
# 2. Explain whether the observations are balanced across categories of the variable location

# %% [markdown]
# **SOLUTION:**
#
# ![image-2](image-2.png)
#
# There are four different locations on the graph. RECIFE was the location having the most amount of claims. Approximately, 44.25 percent of the total claims. The office of SAO LUIS also receives a cosiderable amount of claims. SAO LUIS receives approximately 25.85 percent of the claims. FORTALEZA and NATAL are the two offices that receives the least amount of claims. 15.55 percent and 14.35 percent respectively. As the graph and percentages shows, the metrics are not balanced. Because RECIFE is receiving the most amount of claims, this location should be considered to be evaluated for process enhancement or personnel increase.

# %% [markdown]
# ## Task 3

# %% [markdown]
# Describe the distribution of time to close for all claims. Your answer must include a visualization that shows the distribution.

# %% [markdown]
# **SOLUTION:**
#
# ![image-3](image-3.png)
#
# The distribution of the time to close a claim is right-skewed. The average amount of days that takes to close a claim is 185.568 days. This number can be validated by looking at the graph. As the graph shows, most claim cases were closed within 150 and 200 days.
#
# In addition, there are some claims that took over 248 days to close , however this is uncommon. When assessing what store to help first, the team should see what office has the amount of claims closed over the 248 day period without damaging overall performance.

# %% [markdown]
# ## Task 4

# %% [markdown]
# Describe the relationship between time to close and location. Your answer must include a visualization to demonstrate the relationship.

# %% [markdown]
# **SOLUTION:**
#
# ![image-5](image-5.png)
#
# We will focus the attention to each location to have a better understanding of how to distribute resources to manage the claim process in a better and more efficient way.
#
# Following the graph above, every store is following the standard average discussed previously. As we need more insights and less data noise we will remove the outliers that are beyond 400 so we can have a better understanding and view of the graph. As there are very few outliers passing the 400 mark, we will be ignoring these.

# %% [markdown]
# ![image-6](image-6.png)
#
# Now that we removed the points beyond the 400 mark, we can see all the stores have similar standards. In addition, we must consider the two stores that have the biggest amount of traffic are the RECIFE AND SAO LUIS. These two stores have the most amount of outliers. As discussed previously, RECIFE has the most amount of traffic (44.25 percent of 2000 claims received). Efforts to improve the claim process should be dedicated first to the store located in RECIFE.

# %% [markdown]
# ![image-7](image-7.png)
#
# Finally in this graph we can see the distribution of claims according to the time to close column. The amount of claims that fall in the 75% - 100% percentile  for the RECIFE location is almost the same amount of total claims received in the NATAL location. We can deduce that improving the RECIFE to the best of capabilities can possibly improve 14% of total claims. This is a great chart to observe when evaluating for possible improvements and enhancements.
#
# The store located in SAO LUIS should also be asssessed right after making improvements to the store in RECIFE, as this is the second receiving the most amount of claims. Further analysis will be done after implementing the enhancements required to see the impact of the changes.

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam
